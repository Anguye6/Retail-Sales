# %% [markdown]
# # Project 1 : Retail Sales
#
# Manager: Andrew Nguyen
#
# Member: Emerie Danson
#
# Member: Samantha Mathieu

# %% [markdown]
# Dataset: https://drive.google.com/drive/folders/1_w1TpShrZVKqfyeUqOeTTCw4sBUTa084
#
# Path to dataset:
# *   /content/drive/Shareddrives/MATH 3439 - Spring 2023/data/retail_sales/store_features.csv
# *   /content/drive/Shareddrives/MATH 3439 - Spring 2023/data/retail_sales/sales.csv
# *   /content/drive/Shareddrives/MATH 3439 - Spring 2023/data/retail_sales/stores.csv

# %% [markdown]
# Initial(other) question(s):
#
#
# 1. Should we think about the effect of unemployment on unemployed customers, less employees at the store, both?
# 2. Looks like holiday is a boolean, will we take sale dates and infer which holiday it is?
# 3. What do the holidays look like, is it the day of or is it the week of, etc?
# 4. If the fuel price is high, will the sales be lower?
# 5. How will we account for different store types and sizes when it comes to differences in sales?
# 6. What do the store types mean? (A, B, C)
#
#
#
# Research question(s):
#
#
#
# 1. How do holidays have an effect on retail sales?
# 2. How does unemployement have an effect on retail sales?
# 3. How do fuel prices have an effect on retail sales?
# 4. What combination of the above factors (holidays, fuel price, CPI and unemployment) lead to the best sales weeks? The worst?

# %% [markdown]
# ## Initial responsibilities
#
# ### Manager - Andrew
# Distributing workload
# Exploring the data
#
# *   Distributing workload
# *   Exploring the data
# *   Focusing on a specific research question : How do fuel prices have an effect on retail sales?
# *   Sending found information with group through Slack
#
# ### Member 1 - Emerie
# *   Exploring the data
# *   Focusing on a specific research question : How do holidays have an effect on retail sales?
# *   Sending found information with group through Slack
#
# ### Member 2 - Samantha
# *   Exploring the data
# *   Focusing on a specific research question : How does unemployement have an effect on retail sales?
# *   Sending found information with group through Slack

# %% [markdown]
# ##Manager's section
#
# Initially looking at the dataset, there isn't much explanatory data (column names the holidays, unemployement rate, fuel prices, weekly sales, temperature, markdown price, store type). Most of these are with numerical values. The difficult parts will be modeling data, and what we will use to represent them. Initially the group will go through the data with the focus on their research question, then will proceed with displaying that information through tableau/collab notebook plotting. Each member will start with their initial responsibilities listed above then they will share the information and continue to see how it overall will link together and form a story to present at the end. Each member is given these responsibilities to process the data individually while focusing on a part of the project and sharing that information to the rest of the group then collaborate to create a end goal presentation. To make this project a success, after the individual work, collaborating and making a sensible story to present. Overall, the retail sales dataset isn't complex in understanding so our main focus is making sure that the different parts relate to each other and doesn't go 'off the rails' and makes sense working together and for what is going to be presented.

# %% [markdown]
# Approved by Dr. Savala on: XX/XX/XXXX
